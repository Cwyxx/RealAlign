# %%
### SD-3.5-Medium visualization ###
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
from matplotlib.font_manager import FontProperties

comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=12
)


base_image_dir=f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-3-5-medium"

method_list = [
    "sd-3-5-medium",
    "pick-a-pic-v2-dpo_dataset_160000_pairs",
    "FlowGRPO-PickScore",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all",
    "FlowGRPO-PickScore-next-top_512_images_no_anime_colorfulness_pickscore_002-hpdv3_all-inpainting"
]
method_name_list = [
    "SD-3.5-M",
    "Diffusion-DPO",
    "FlowGRPO",
    "Ours",
    "FlowGRPO+Ours",
]
ckpt_list = [ 0, 4900, 0, 450, 300]
dataset_name_list = [  "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts", "drawbench-unique", "drawbench-unique", "drawbench-unique", "HPDv2-anime" ] #  "pick_a_pic_v2", "HPDv2-paintings",  "drawbench-unique" "pick_a_pic_v2" "HPDv2-anime", "pick_a_pic_v2", "pick_a_pic_v2",  "drawbench-unique", "drawbench-unique", "HPDv2-paintings", "HPDv2-anime", "HPDv2-anime", "pick_a_pic_v2", "pick_a_pic_v2", "pick_a_pic_v2" "HPDv2-photo", "HPDv2-photo", "pick_a_pic_v2",  "pick_a_pic_v2",  "pick_a_pic_v2",  "pick_a_pic_v2" "drawbench-unique", "HPDv2-paintings", "HPDv2-photo", "HPDv2-photo" "HPDv2-paintings",  "HPDv2-anime"  "HPDv2-anime", "HPDv2-anime"
seed_list = [ 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, ] #  42 123 42 42, 42, 42 42, 42, 42, 42, 42, 42, 42, 42 42, 42, 42, 42, 42, 1000, 42 42, 42, 42, 42, 
image_id_list = [ 334, 1175, 1415, 1076, 205, 53, 243, 264, 10, 35, 37, 9 ] # 186 173 328 9, 399, 362,  112, 51, 188, 102, 158, 355, 236, 200 87, 71, 86, 362, 383, 143, 37, 140, 47, 153, 9, 44, 102,
num_rows = len(image_id_list)
num_columns = len(method_list)

fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2 * num_rows), dpi=200)

if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [axes]

for row_idx, (seed, image_id, dataset_name) in enumerate(zip(seed_list, image_id_list, dataset_name_list)):
    for col_idx, (method, ckpt, method_name) in enumerate(zip(method_list, ckpt_list, method_name_list)):
        image_path = os.path.join(base_image_dir, f"generate_images_seed_{seed}/{dataset_name}", method, f"ckpt-{ckpt}", "images", f"{image_id:05d}.png")
        print(image_path)
        img = mpimg.imread(image_path)
        axes[row_idx][col_idx].imshow(img)
        axes[row_idx][col_idx].axis('off')
        
        if row_idx == 0:
            axes[row_idx][col_idx].set_title(method_name, pad=10, fontproperties=comic_font)

plt.subplots_adjust(wspace=0.02, hspace=0.02)
# plt.tight_layout()
# plt.savefig('SD-3-5-Medium-visualization.pdf', format='pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
### SD-3.5-Medium visualization-v2 ###
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.font_manager import FontProperties

# 字体配置
comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=12
)

base_image_dir = f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-3-5-medium"

# 配置列表
method_list = [
    "sd-3-5-medium",
    # "pick-a-pic-v2-dpo_dataset_160000_pairs",
    "FlowGRPO-PickScore",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all",
    "FlowGRPO-PickScore-next-top_512_images_no_anime_colorfulness_pickscore_002-hpdv3_all-inpainting"
]
method_name_list = ["SD-3.5-M", "FlowGRPO", "Ours", "FlowGRPO+Ours"]
ckpt_list = [0, 0, 450, 300]

dataset_name_list = [ "partiprompts", "partiprompts", "partiprompts", "HPDv2-anime"] # "pick_a_pic_v2",
seed_list = [ 42, 42, 42, 42] # 42,
image_id_list = [ 1175, 243, 264, 9] # 186,

# --- 核心交换逻辑 ---
num_rows = len(method_list)    # 每一行是一个方法
num_columns = len(image_id_list) # 每一列是一个样本

fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2 * num_rows), dpi=300)

# 确保 axes 始终是二维数组
if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [[ax] for ax in axes]

# --- 核心绘制逻辑 ---
for row_idx, (method, ckpt, method_name) in enumerate(zip(method_list, ckpt_list, method_name_list)):
    for col_idx, (seed, image_id, dataset_name) in enumerate(zip(seed_list, image_id_list, dataset_name_list)):
        
        image_path = os.path.join(base_image_dir, f"generate_images_seed_{seed}/{dataset_name}", method, f"ckpt-{ckpt}", "images", f"{image_id:05d}.png")
        
        ax = axes[row_idx][col_idx]
        img = mpimg.imread(image_path)
        ax.imshow(img, aspect="auto") # nearest 减少边缘模糊
        
        ax.set_xticks([])
        ax.set_yticks([])
        # 隐藏边框，防止紧贴时出现双倍粗细的线条
        for spine in ax.spines.values():
            spine.set_visible(False)
            
        # 在第一列设置垂直 ylabel
        if col_idx == 0:
            ax.set_ylabel(
                method_name, 
                fontproperties=comic_font, 
                # rotation 默认就是 90 (垂直)
                va='center', 
                labelpad=10
            )

plt.subplots_adjust(wspace=0.0, hspace=0.0)
plt.savefig("SD-3.5-Medium-visualization-v2.pdf", format="pdf", bbox_inches="tight", dpi=300)
plt.show()

# %%
### SD-1.5-Visualization-v3 ###
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.font_manager import FontProperties

# 字体配置
comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=14
)

base_image_dir = f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-v1-5"

# 配置列表
method_list = [
    "sd-v1-5",
    # "spo-official",
    "dpo-official",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_ckpt_1600-dpo_2000_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_inpainting",
    "dpo_official-irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_ckpt_1600-dpo_2000_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-inpainting"
]
method_name_list = ["SD-1.5", "Diffusion-DPO", "Ours", "Diffusion-DPO+Ours"]
ckpt_list = [0, 0, 800, 800]

dataset_name_list = [ "pick_a_pic_v2", "partiprompts", "pick_a_pic_v2", "partiprompts" ]
seed_list = [42, 42, 123, 42]
image_id_list = [357, 238, 279, 940]

# --- 核心交换逻辑 ---
num_rows = len(method_list)    # 每一行是一个方法
num_columns = len(image_id_list) # 每一列是一个样本

fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2 * num_rows), dpi=300)

# 确保 axes 始终是二维数组
if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [[ax] for ax in axes]

# --- 核心绘制逻辑 ---
for row_idx, (method, ckpt, method_name) in enumerate(zip(method_list, ckpt_list, method_name_list)):
    for col_idx, (seed, image_id, dataset_name) in enumerate(zip(seed_list, image_id_list, dataset_name_list)):
        
        image_path = os.path.join(base_image_dir, f"generate_images_seed_{seed}/{dataset_name}", method, f"ckpt-{ckpt}", "images", f"{image_id:05d}.png")
        
        ax = axes[row_idx][col_idx]
        img = mpimg.imread(image_path)
        ax.imshow(img, aspect="auto") # nearest 减少边缘模糊
        
        ax.set_xticks([])
        ax.set_yticks([])
        # 隐藏边框，防止紧贴时出现双倍粗细的线条
        for spine in ax.spines.values():
            spine.set_visible(False)
            
        # 在第一列设置垂直 ylabel
        if col_idx == 0:
            ax.set_ylabel(
                method_name, 
                fontproperties=comic_font, 
                # rotation 默认就是 90 (垂直)
                va='center', 
                labelpad=10
            )

plt.subplots_adjust(wspace=0.0, hspace=0.0)
plt.savefig("SD-1.5-Visualization-v2.pdf", format="pdf", bbox_inches="tight", dpi=300)
plt.show()

# %%
### SD-3.5-Medium-visualization-v3 ###
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.font_manager import FontProperties

# 字体配置
comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=14
)

base_image_dir = f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-3-5-medium"

# 配置列表
method_list = [
    "sd-3-5-medium",
    "FlowGRPO-PickScore",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all",
    "FlowGRPO-PickScore-next-top_512_images_no_anime_colorfulness_pickscore_002-hpdv3_all-inpainting"
]
method_name_list = ["SD-3.5-M", "FlowGRPO", "Ours", "FlowGRPO+Ours"] # 
ckpt_list = [0, 0, 450, 300]

dataset_name_list = [ "partiprompts", "partiprompts", "HPDv2-anime"] # "partiprompts",
seed_list = [42, 42, 42] # 42
image_id_list = [ 243, 264, 9] # 1175, 

# --- 逻辑交换：现在行是样本，列是方法 ---
num_rows = len(image_id_list)    # 样本数 -> 行
num_columns = len(method_list)   # 方法数 -> 列

fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2 * num_rows), dpi=300)

# 确保 axes 始终是二维数组
if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [[ax] for ax in axes]

# --- 核心绘制逻辑 ---
# 外层循环遍历行 (样本)
for row_idx, (seed, image_id, dataset_name) in enumerate(zip(seed_list, image_id_list, dataset_name_list)):
    # 内层循环遍历列 (方法)
    for col_idx, (method, ckpt, method_name) in enumerate(zip(method_list, ckpt_list, method_name_list)):
        
        image_path = os.path.join(base_image_dir, f"generate_images_seed_{seed}/{dataset_name}", method, f"ckpt-{ckpt}", "images", f"{image_id:05d}.png")
        ax = axes[row_idx][col_idx]
        
        try:
            img = mpimg.imread(image_path)
            ax.imshow(img, aspect="auto")
        except FileNotFoundError:
            ax.text(0.5, 0.5, "Image Not Found", ha='center', va='center', fontsize=8)
        
        ax.set_xticks([])
        ax.set_yticks([])
        # 隐藏边框
        for spine in ax.spines.values():
            spine.set_visible(False)
            
        # 在第一行设置顶部标题 (方法名)
        if row_idx == 0:
            ax.set_title(method_name, fontproperties=comic_font, pad=10)
            
        # # 在第一列设置左侧标签 (样本信息)
        # if col_idx == 0:
        #     ax.set_ylabel(
        #         f"{dataset_name}\nID: {image_id}", 
        #         fontproperties=comic_font, 
        #         labelpad=10,
        #         rotation=90,
        #         va='center'
        #     )

# 调整间距，wspace和hspace设为较小值可以紧凑排布
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig("SD-3.5-Medium-visualization-v3.pdf", format="pdf", bbox_inches="tight", dpi=300)
plt.show()
