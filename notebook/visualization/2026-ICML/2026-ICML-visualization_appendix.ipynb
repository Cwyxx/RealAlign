# %%
### SD-3.5-Medium visualization ###
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
from matplotlib.font_manager import FontProperties

comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=14
)


base_image_dir=f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-3-5-medium"

method_list = [
    "sd-3-5-medium",
    "pick-a-pic-v2-dpo_dataset_160000_pairs",
    "FlowGRPO-PickScore",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all",
    "FlowGRPO-PickScore-next-top_512_images_no_anime_colorfulness_pickscore_002-hpdv3_all-inpainting"
    # "FlowGRPO-PickScore-next-irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all",
    # "irl-top_512_images_pickscore_002-civitai_top_sfw_images-uids_lr_0.0002_ckpt_3200-dpo_top_512_images_pickscore_002-civitai_top_sfw_images-uids",
    # "GRPO-Guard",
    # "DiffusionNFT",
]
method_name_list = [
    "SD-3.5-M",
    "Diffusion-DPO",
    "FlowGRPO",
    "Ours",
    "FlowGRPO+Ours"
]
# # HPDv2-all
# ckpt_list = [ 0, 450, 400, 0, 0, 0 ]
# image_id_list = [ 11, 29, 2314, 1093, 1711, 2065, 2960, ]  # 1767, 1114, 979, 1869, 2460, 2750, 3173
# dataset_name_list = [ "HPDv2-all" ] * len(image_id_list)
# seed_list = [ 42 ] * len(image_id_list) #  
# # HPDv2-all

# Partiprompts
ckpt_list = [ 0, 4900, 0, 450, 300 ]
dataset_name_list = [ "pick_a_pic_v2", "pick_a_pic_v2", "partiprompts",  "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts", "partiprompts" ] 
seed_list = [ 42, 42, 42, 42, 42, 42, 42, 42, 42,  42, 42,  ] #  42 42 
image_id_list = [ 255, 368, 269, 1175, ] # 110 1092, 658, 385, 250, 264,
# Partiprompts
num_rows = len(image_id_list)
num_columns = len(method_list)

print(f"num_rows: {num_rows}, num_columns: {num_columns}")
fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2 * num_rows), dpi=300)

if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [axes]

for row_idx, (seed, image_id, dataset_name) in enumerate(zip(seed_list, image_id_list, dataset_name_list)):
    for col_idx, (method, ckpt, method_name) in enumerate(zip(method_list, ckpt_list, method_name_list)):
        image_path = os.path.join(base_image_dir, f"generate_images_seed_{seed}/{dataset_name}", method, f"ckpt-{ckpt}", "images", f"{image_id:05d}.png")
        img = mpimg.imread(image_path)
        axes[row_idx][col_idx].imshow(img, aspect='auto')
        axes[row_idx][col_idx].axis('off')
        
        axes[row_idx][col_idx].set_xticks([])
        axes[row_idx][col_idx].set_yticks([])
        for spine in axes[row_idx][col_idx].spines.values():
            spine.set_visible(False)
        
        if row_idx == 0:
            axes[row_idx][col_idx].set_title(method_name, pad=10, fontproperties=comic_font)

plt.subplots_adjust(wspace=0, hspace=0)
# plt.tight_layout()
plt.savefig('SD-3-5-Medium-visualization_appendix.pdf', format='pdf', bbox_inches='tight', dpi=300)
plt.show()

# %%
### SD-1.5 visualization ###
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
from matplotlib.font_manager import FontProperties

comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=14
)

dataset_name="pick_a_pic_v2"
base_image_dir=f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-v1-5"

method_list = [
    "sd-v1-5",
    "spo-official",
    "dpo-official",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_ckpt_1600-dpo_2000_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_inpainting",
    "dpo_official-irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_ckpt_1600-dpo_2000_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-inpainting",
]
method_name_list = [
    "SD-1.5",
    "SPO",
    "Diffusion-DPO",
    "Ours",
    "Diffusion-DPO+Ours"    
]
ckpt_list = [ 0, 0, 0, 800, 800 ]
# paper:
# seed_list = [42, 1000, 123 ] # 123 456 456 
# image_id_list = [357, 438, 279 ] # 100 471 100
image_id_list_partiprompts = [ 152, 159, ] #   631  265 1252, 152 159 865, 631, 615, 
dataset_name_list_partiprompts = ["partiprompts"] * len(image_id_list_partiprompts)
seed_list_partiprompts = [42] * len(image_id_list_partiprompts)
dataset_name_list = dataset_name_list_partiprompts + [ "pick_a_pic_v2",  "pick_a_pic_v2", "pick_a_pic_v2", "pick_a_pic_v2", "pick_a_pic_v2", "pick_a_pic_v2" ]
seed_list = seed_list_partiprompts + [ 456, 456, 456, 456, ] # 456, 123, 123, 456, 456, 1000
image_id_list = image_id_list_partiprompts + [  321, 195, ] #  213, 100, 279, 417, 471, 423 406 254 316 36
# seed_list = [42, 123, 456, 789, 1000 ] # 1000
# # image_id_list = [285, 285, 285, 285, 285] # 423 406 254 316 36
# # image_id_list = [348, 348, 348, 348, 348]
# # image_id_list = [438, 438, 438, 438, 438]
# image_id_list = [288, 288, 288, 288, 288]
num_rows = len(image_id_list)
num_columns = len(method_list)

fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2 * num_rows), dpi=200)

if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [axes]

for row_idx, (seed, dataset_name, image_id) in enumerate(zip(seed_list, dataset_name_list, image_id_list)):
    for col_idx, (method, ckpt, method_name) in enumerate(zip(method_list, ckpt_list, method_name_list)):
        image_path = os.path.join(base_image_dir, f"generate_images_seed_{seed}/{dataset_name}", method, f"ckpt-{ckpt}", "images", f"{image_id:05d}.png")
        img = mpimg.imread(image_path)
        axes[row_idx][col_idx].imshow(img, aspect='auto')
        axes[row_idx][col_idx].axis('off')
        
        axes[row_idx][col_idx].set_xticks([])
        axes[row_idx][col_idx].set_yticks([])
        for spine in axes[row_idx][col_idx].spines.values():
            spine.set_visible(False)
        
        if row_idx == 0:
            axes[row_idx][col_idx].set_title(method_name, pad=10, fontproperties=comic_font)

plt.subplots_adjust(wspace=0, hspace=0)
# plt.tight_layout()
plt.savefig('SD-1-5-visualization-appendix.pdf', format='pdf', bbox_inches='tight', dpi=300)
plt.show()

# %%
### SD-3.5-Medium visualization ###
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
from matplotlib.font_manager import FontProperties

comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=14
)


base_image_dir=f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-3-5-medium/generate_images/OneIG-Bench/anime"

method_list = [
    "sd-3-5-medium",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-ckpt_450",
    "irl-top_512_images_pickscore_002-civitai_top_sfw_images-uids_lr_0.0002_ckpt_3200-dpo_top_512_images_pickscore_002-civitai_top_sfw_images-uids-ckpt_400",
    "FlowGRPO-PickScore",
    "GRPO-Guard",
    "DiffusionNFT",
]
method_name_list = [
    "SD-3.5-M",
    "AFPO (HPDv3)",
    "AFPO (Civitai-top)",
    "FlowGRPO",
    "GRPO-Guard",
    "DiffusionNFT"
]
score_dict = {
    115: {
        "SD-3.5-M": 0.3329759854823351,
        "AFPO (HPDv3)": 0.32619080506265163,
        "AFPO (Civitai-top)": 0.3589451275765896,
        "FlowGRPO": 0.1488037109375,
        "GRPO-Guard": 0.0570068359375,
        "DiffusionNFT": 0.06640625
    },
    123: {
        "SD-3.5-M": 0.5425201505422592,
        "AFPO (HPDv3)": 0.3925854489207268,
        "AFPO (Civitai-top)": 0.42856665700674057,
        "FlowGRPO": 0.3243686072528362,
        "GRPO-Guard": 0.24308109283447266,
        "DiffusionNFT": 0.09541263245046139
    },
    184: {
        "SD-3.5-M": 0.47071442380547523,
        "AFPO (HPDv3)": 0.5107076950371265,
        "AFPO (Civitai-top)": 0.46961038559675217,
        "FlowGRPO": 0.39886443316936493,
        "GRPO-Guard": 0.34727221354842186,
        "DiffusionNFT": 0.2620247080922127
    },
    234: {
        "SD-3.5-M": 0.29461897211149335,
        "AFPO (HPDv3)": 0.29465890815481544,
        "AFPO (Civitai-top)": 0.25146484375,
        "FlowGRPO": 0.185546875,
        "GRPO-Guard": 0.1865234375,
        "DiffusionNFT": 0.1358642578125
    }
}
# seed 值对应 2x2 网格位置：0=左上角, 1=右上角, 2=左下角, 3=右下角
tmp_seed_list = [ 0, 1, 2, 3]
tmp_image_id_list = [ 147 ] * len(tmp_seed_list)
seed_list = [ 0, 0, 1, 0, 0, 0] + tmp_seed_list
image_id_list = [175, 115, 234, 184, 160, 105] + tmp_image_id_list
# seed_list = [ 0, 0, 1, 0, 0]
# image_id_list = [175, 115, 234, 184, 160]
# seed_list = [ 0, 1, 0, 0,  ]
# image_id_list = [115, 234, 123, 184,  ]
num_rows = len(image_id_list)
num_columns = len(method_list)

print(f"num_rows: {num_rows}, num_columns: {num_columns}")
fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2 * num_rows), dpi=200)

if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [axes]

for row_idx, (seed, image_id) in enumerate(zip(seed_list, image_id_list)):
    for col_idx, (method, ckpt, method_name) in enumerate(zip(method_list, ckpt_list, method_name_list)):
        image_path = os.path.join(base_image_dir, method, f"{image_id:03d}.webp")
        img = mpimg.imread(image_path)
        
        # 从2x2网格中根据seed值提取对应的图像
        # seed: 0=左上角, 1=右上角, 2=左下角, 3=右下角
        h, w = img.shape[0], img.shape[1]
        h_half, w_half = h // 2, w // 2
        
        if seed == 0:  # 左上角
            img_extracted = img[0:h_half, 0:w_half]
        elif seed == 1:  # 右上角
            img_extracted = img[0:h_half, w_half:w]
        elif seed == 2:  # 左下角
            img_extracted = img[h_half:h, 0:w_half]
        elif seed == 3:  # 右下角
            img_extracted = img[h_half:h, w_half:w]
        else:
            img_extracted = img  # 如果seed不在0-3范围内，显示完整图像
        
        axes[row_idx][col_idx].imshow(img_extracted)
        axes[row_idx][col_idx].axis('off')
        
        if row_idx == 0:
            axes[row_idx][col_idx].set_title(method_name, pad=10, fontproperties=comic_font)

plt.subplots_adjust(wspace=0.02, hspace=0.02)
# plt.tight_layout()
# plt.savefig('SD-3-5-Medium-visualization_appendix_oneig_style.pdf', format='pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patheffects as PathEffects # [新增 1] 导入路径效果库用于描边
from matplotlib.font_manager import FontProperties

comic_font = FontProperties(
    fname="/data3/chenweiyan/notebook/fine-tune-diffusion/spo_gitee/notebook/visualization/Comic Sans MS.ttf",
    size=12
)


base_image_dir=f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-3-5-medium/generate_images/OneIG-Bench/anime"

method_list = [
    "sd-3-5-medium",
    "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-ckpt_450",
    "irl-top_512_images_pickscore_002-civitai_top_sfw_images-uids_lr_0.0002_ckpt_3200-dpo_top_512_images_pickscore_002-civitai_top_sfw_images-uids-ckpt_400",
    "FlowGRPO-PickScore",
    "GRPO-Guard",
    "DiffusionNFT",
]
method_name_list = [
    "SD-3.5-M",
    "AFPO (HPDv3)",
    "AFPO (Civitai-top)",
    "FlowGRPO",
    "GRPO-Guard",
    "DiffusionNFT"
]
score_dict = {
    115: {
        "SD-3.5-M": 0.3329759854823351,
        "AFPO (HPDv3)": 0.32619080506265163,
        "AFPO (Civitai-top)": 0.3589451275765896,
        "FlowGRPO": 0.1488037109375,
        "GRPO-Guard": 0.0570068359375,
        "DiffusionNFT": 0.06640625
    },
    50: {
        "SD-3.5-M": 0.2514026015996933,
        "AFPO (HPDv3)": 0.29819450026843697,
        "AFPO (Civitai-top)": 0.25174554565455765,
        "FlowGRPO": 0.22518767975270748,
        "GRPO-Guard": 0.16484668757766485,
        "DiffusionNFT": 0.13192570890532807
    },
    123: {
        "SD-3.5-M": 0.5425201505422592,
        "AFPO (HPDv3)": 0.3925854489207268,
        "AFPO (Civitai-top)": 0.42856665700674057,
        "FlowGRPO": 0.3243686072528362,
        "GRPO-Guard": 0.24308109283447266,
        "DiffusionNFT": 0.09541263245046139
    },
    184: {
        "SD-3.5-M": 0.47071442380547523,
        "AFPO (HPDv3)": 0.5107076950371265,
        "AFPO (Civitai-top)": 0.46961038559675217,
        "FlowGRPO": 0.39886443316936493,
        "GRPO-Guard": 0.34727221354842186,
        "DiffusionNFT": 0.2620247080922127
    },
    234: {
        "SD-3.5-M": 0.29461897211149335,
        "AFPO (HPDv3)": 0.29465890815481544,
        "AFPO (Civitai-top)": 0.25146484375,
        "FlowGRPO": 0.185546875,
        "GRPO-Guard": 0.1865234375,
        "DiffusionNFT": 0.1358642578125
    }
}

seed_list = [ 0, 0, 0 ]
image_id_list = [115, 50, 184, ]
num_rows = len(image_id_list)
num_columns = len(method_list)

fig, axes = plt.subplots(num_rows, num_columns, figsize=(2 * num_columns, 2.4 * num_rows), dpi=200)

if num_rows == 1:
    axes = [axes]
if num_columns == 1:
    axes = [axes]

for row_idx, (seed, image_id) in enumerate(zip(seed_list, image_id_list)):
    for col_idx, (method, method_name) in enumerate(zip(method_list, method_name_list)):
        image_path = os.path.join(base_image_dir, method, f"{image_id:03d}.webp")
        
        if not os.path.exists(image_path):
            continue
            
        img = mpimg.imread(image_path)
        
        # 裁剪逻辑
        h, w = img.shape[0], img.shape[1]
        h_half, w_half = h // 2, w // 2
        
        if seed == 0: img_extracted = img[0:h_half, 0:w_half]
        elif seed == 1: img_extracted = img[0:h_half, w_half:w]
        elif seed == 2: img_extracted = img[h_half:h, 0:w_half]
        elif seed == 3: img_extracted = img[h_half:h, w_half:w]
        else: img_extracted = img

        ax = axes[row_idx][col_idx]
        ax.imshow(img_extracted)
        ax.axis('off')
        
        # 获取分数
        current_score = score_dict.get(image_id, {}).get(method_name, 0.0)
        
        # [调整 2] 添加下方文字
        # y=-0.04: 位于坐标轴底部边缘的下方
        # va='top': 文字顶部对齐坐标点，保证文字向下延伸
        # color='black': 黑色文字
        ax.text(0.5, -0.04, f"score: {current_score:.3f}", 
                transform=ax.transAxes, 
                color='black', 
                fontsize=10,  # 根据图片大小适当调整字号
                ha='center', 
                va='top',
                fontproperties=comic_font)
        
        if row_idx == 0:
            ax.set_title(method_name, pad=10, fontproperties=comic_font)

# [调整 3] 增大 hspace，防止文字与下一行图片重叠
plt.subplots_adjust(wspace=0.02, hspace=0.1) 
plt.savefig('SD-3-5-Medium-visualization_appendix_oneig_style.pdf', format='pdf', bbox_inches='tight', dpi=200)
plt.show()
