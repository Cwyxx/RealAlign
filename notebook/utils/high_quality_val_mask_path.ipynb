# %%
import os
import pandas as pd

base_csv_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/paired_real_generated_dataset/high_quality_val/high_quality_val.csv"
mask_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/mask/0a0aa47e-95b3-412f-9140-8ac1ab2c0e6e.png"

# 读取 CSV 文件
df = pd.read_csv(base_csv_path)

# 添加 mask_image_path 列，所有行的值都设置为指定的路径
df['mask_image_path'] = mask_path

# 保存回 CSV 文件
df.to_csv(base_csv_path, index=False)

print(f"已成功添加 mask_image_path 列，共 {len(df)} 行")
print(f"CSV 文件已保存到: {base_csv_path}")
# Out:
# 已成功添加 mask_image_path 列，共 18315 行
# CSV 文件已保存到: /data_center/data2/dataset/chenwy/21164-data/dpo_dataset/paired_real_generated_dataset/high_quality_val/high_quality_val.csv
