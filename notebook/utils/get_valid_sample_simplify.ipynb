# %%
#### random sample PickScore_GAP > 0.02 ####
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import csv

# ## sam_next_inpainting ###
# base_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/sam_next_inpainting/HPDv3/random_top_5_mask"
# win_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/sam_next_inpainting/HPDv3/random_top_5_mask/real"
# lose_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/sam_next_inpainting/HPDv3/random_top_5_mask/fake"
# ## sam_next_inpainting ###

# ### u2net_next_inpainting ###
# base_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3"
# win_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/real"
# lose_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/fake"
# ### u2net_next_inpainting ###

all_information_df = pd.read_csv("/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/civitai-top-sfw-images-with-metadata/uid_prompt.csv", dtype={"uid": str})
base_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/civitai-top-sfw-images-with-metadata"
win_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/civitai-top-sfw-images-with-metadata/real"
lose_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/civitai-top-sfw-images-with-metadata/fake"

pickscore_df = pd.read_csv(os.path.join(base_dir, "pickscore/pickscore_score.csv"), dtype={"uid": str})
# anime_df = pd.read_csv("/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/qwen3_anime/qwen3_anime.csv", dtype={"uid": str})
# colorfulness_df = pd.read_csv("/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/colorfulness/colorfulness_score.csv", dtype={"uid": str})

# valid_real_image_uids = anime_df[anime_df['anime'] == 'no']['uid'].tolist()
valid_pickscore_uids = pickscore_df[pickscore_df['real_image_score'] - pickscore_df['fake_image_score'] > 0.02]['uid'].tolist()
# colorfulness_df = colorfulness_df[colorfulness_df['uid'].isin(valid_real_image_uids)]
# avg_colorfulness = colorfulness_df['real_image_score'].mean()
# valid_colorfulness_uids = colorfulness_df[colorfulness_df['real_image_score'] > avg_colorfulness]['uid'].tolist()

# valid_uids = list(set(valid_real_image_uids) & set(valid_pickscore_uids) & set(valid_colorfulness_uids))
valid_uids = valid_pickscore_uids

print(f"valid_uids: {len(valid_uids)}")
print(f"valid_pickscore_uids: {len(valid_pickscore_uids)} / {len(pickscore_df)}")
# print(f"valid_colorfulness_uids: {len(valid_colorfulness_uids)} / {len(colorfulness_df)}")
# print(f"valid_real_image_uids: {len(valid_real_image_uids)} / {len(anime_df)}")

# random.seed(42)
# sample_num = 5376 # 4864
# valid_uids = random.sample(valid_uids, sample_num)

# ext_list = [".png", ".PNG", ".jpg", ".jpeg", ".JPG", ".JPEG"]
# total_information_list = []
# for uid in valid_uids:
#     for ext in ext_list:
#         win_image_path = os.path.join(win_image_dir, f"{uid}{ext}")
#         if os.path.exists(win_image_path):
#             break
#     if win_image_path is None:
#         print(f"Warning: No valid image found for uid {uid}")
#         continue
    
#     for ext in ext_list:
#         lose_image_path = os.path.join(lose_image_dir, f"{uid}{ext}")
#         if os.path.exists(lose_image_path):
#             break
#     if lose_image_path is None:
#         print(f"Warning: No valid image found for uid {uid}")
#         continue
    
#     prompt = all_information_df.loc[all_information_df['uid'] == uid, 'prompt'].values[0]
#     total_information_list.append({
#         "uid": uid,
#         "prompt": prompt,
#         "win_image_path": win_image_path,
#         "lose_image_path": lose_image_path
#     })
    
# print(f"\nFinal valid samples: {len(total_information_list)}")
# final_output_path = os.path.join(base_dir, f"random_{sample_num}_images_pickscore_0.02-civitai_top_sfw_images-uids.csv")
# pd.DataFrame(total_information_list).to_csv(    
#     final_output_path, 
#     index=False, 
#     encoding='utf-8',
#     quoting=csv.QUOTE_ALL,  # 所有字段都用引号包裹
#     escapechar='\\',  # 转义字符
#     doublequote=True  # 引号内的引号用双引号表示
# )
# print(f"Saved to: {final_output_path}")

# %%
#### Get highest real image pickscore and anime is no and pickscore (gap > 0.02) uid ####
import os
import pandas as pd
import matplotlib.pyplot as plt

threshold = 0.02
real_colorfulness_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/no_anime_colorfulness-hpdv3_all-uids.csv"
# anime_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/qwen3_anime/qwen3_anime.csv"
# colorfulness_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/colorfulness/colorfulness_score.csv"
pickscore_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3/pickscore/pickscore_score.csv"

# all_information_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/top_4096_images.csv"
# pickscore_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/pickscore/pickscore_score.csv"
# anime_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/qwen3_anime/qwen3_anime.csv"
# colorfulness_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/colorfulness/colorfulness_score.csv"

real_colorfulness_df = pd.read_csv(real_colorfulness_csv_file_path, dtype={"uid": str})
pickscore_df = pd.read_csv(pickscore_csv_file_path, dtype={"uid": str})
# anime_df = pd.read_csv(anime_csv_file_path, dtype={"uid": str})
# colorfulness_df = pd.read_csv(colorfulness_csv_file_path, dtype={"uid": str})


valid_pickscore_uids = pickscore_df[pickscore_df['real_image_score'] - pickscore_df['fake_image_score'] > threshold]['uid'].tolist()
real_colorfulness_uids = real_colorfulness_df['uid'].tolist()
# valid_real_image_uids = anime_df[anime_df['anime'] == 'no']['uid'].tolist()
# colorfulness_df = colorfulness_df[colorfulness_df['uid'].isin(valid_real_image_uids)]

valid_uids = list(set(real_colorfulness_uids) & set(valid_pickscore_uids))
print(f"valid_uids: {len(valid_uids)} / {len(real_colorfulness_uids)}")


# 从 valid_uids 中筛选出 pickscore real_image_score 值最高的前 N 张图片
# 可配置参数：选择前 N 个样本
TOP_N = 512

# Step 1: 从 pickscore_df 中筛选出 uid 在 valid_uids 中的行
pickscore_valid_df = pickscore_df[pickscore_df['uid'].isin(valid_uids)].copy()
print(f"\nStep 1: Pickscore samples in valid_uids: {len(pickscore_valid_df)}")

# Step 2: 按照 real_image_score 降序排序
pickscore_valid_df = pickscore_valid_df.sort_values('real_image_score', ascending=False)

# Step 3: 取前 N 个
top_N_df = pickscore_valid_df.head(TOP_N)
print(f"Step 2: Top {TOP_N} samples selected")
print(f"  Real image score range: {top_N_df['real_image_score'].min():.4f} - {top_N_df['real_image_score'].max():.4f}")
print(f"  Score gap range: {(top_N_df['real_image_score'] - top_N_df['fake_image_score']).min():.4f} - {(top_N_df['real_image_score'] - top_N_df['fake_image_score']).max():.4f}")

# 获取 top N 的 uid 列表
top_N_uids = top_N_df['uid'].tolist()
print(f"\nTop {TOP_N} UIDs selected: {len(top_N_uids)}")

# Step 4: Generate CSV file with image paths
ext_list = [".png", ".PNG", ".jpg", ".jpeg", ".JPG", ".JPEG"]
real_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3/real"
fake_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3/fake"
# mask_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/mask"
final_information_list = []
# for index, row in top_N_df.iterrows():
#     uid = row["uid"]
for uid in top_N_uids:
    win_image_path, lose_image_path, mask_image_path = None, None, None
    
    for ext in ext_list:
        win_image_path = os.path.join(real_image_dir, f"{uid}{ext}")
        if os.path.exists(win_image_path):
            break
        win_image_path = None
        
    if win_image_path is None:
        print(f"Warning: No valid image found for uid {uid}")
        continue
    
    for ext in ext_list:
        lose_image_path = os.path.join(fake_image_dir, f"{uid}{ext}")
        if os.path.exists(lose_image_path):
            break
        lose_image_path = None
        
    if lose_image_path is None:
        print(f"Warning: No valid image found for uid {uid}")
        continue
    

    
    prompt = real_colorfulness_df.loc[real_colorfulness_df['uid'] == uid, 'prompt'].values[0]
    final_information_list.append({
        'uid': uid,
        'prompt': prompt,
        'win_image_path': win_image_path,
        'lose_image_path': lose_image_path,
    })

# print(f"\nFinal valid samples: {len(final_information_list)}")
final_output_path = f"/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3/top_{TOP_N}_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv"
pd.DataFrame(final_information_list).to_csv(final_output_path, index=False)
print(f"Saved to: {final_output_path}")
# Out:
# valid_uids: 5531 / 10475
#
# Step 1: Pickscore samples in valid_uids: 5531
# Step 2: Top 512 samples selected
#   Real image score range: 0.8913 - 0.9914
#   Score gap range: 0.0201 - 0.2025
#
# Top 512 UIDs selected: 512
# Saved to: /data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3/top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv

# %%
#### Get random real image and above-average colorfulness ####
import os
import random
import pandas as pd
import matplotlib.pyplot as plt

all_information_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/HPDv3/real_images_uid_prompt.csv"
# pickscore_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/pickscore/pickscore_score.csv"
anime_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/qwen3_anime/qwen3_anime.csv"
colorfulness_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/colorfulness/colorfulness_score.csv"

all_information_df = pd.read_csv(all_information_csv_file_path, dtype={"uid": str})
pickscore_df = pd.read_csv(pickscore_csv_file_path, dtype={"uid": str})
anime_df = pd.read_csv(anime_csv_file_path, dtype={"uid": str})
colorfulness_df = pd.read_csv(colorfulness_csv_file_path, dtype={"uid": str})

valid_real_image_uids = anime_df[anime_df['anime'] == 'no']['uid'].tolist()
# valid_pickscore_uids = pickscore_df[pickscore_df['real_image_score'] - pickscore_df['fake_image_score'] > 0.02]['uid'].tolist()
colorfulness_df = colorfulness_df[colorfulness_df['uid'].isin(valid_real_image_uids)]
avg_colorfulness = colorfulness_df['real_image_score'].mean()
valid_colorfulness_uids = colorfulness_df[colorfulness_df['real_image_score'] > avg_colorfulness]['uid'].tolist()

valid_uids = list(set(valid_real_image_uids) & set(valid_colorfulness_uids))
# valid_uids = valid_pickscore_uids
print(f"valid_uids: {len(valid_uids)}")
# print(f"valid_real_image_uids: {len(valid_real_image_uids)} / {len(anime_df)}")
# print(f"valid_colorfulness_uids: {len(valid_colorfulness_uids)} / {len(colorfulness_df)}; avg_colorfulness: {avg_colorfulness:.4f}")
# print(f"valid_pickscore_uids: {len(valid_pickscore_uids)} / {len(pickscore_df)}")

# 从 valid_uids 中随机采样 N 张图片
# 可配置参数：选择前 N 个样本
TOP_N = 512

# 设置随机种子
random.seed(42)

# Step 1: 直接从 valid_uids 中随机选择 TOP_N 个 uid
top_N_uids = random.sample(valid_uids, min(TOP_N, len(valid_uids)))
print(f"\nStep 1: Randomly selected {len(top_N_uids)} UIDs from {len(valid_uids)} valid_uids")
print(f"Top {TOP_N} UIDs selected: {len(top_N_uids)}")

# Step 4: Generate CSV file with image paths
ext_list = [".png", ".PNG", ".jpg", ".jpeg", ".JPG", ".JPEG"]
# real_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/real"
# fake_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/fake"
real_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/real"
fake_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/fake"
# mask_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/mask"
final_information_list = []
for uid in top_N_uids:
    win_image_path, lose_image_path, mask_image_path = None, None, None
    
    for ext in ext_list:
        win_image_path = os.path.join(real_image_dir, f"{uid}{ext}")
        if os.path.exists(win_image_path):
            break
        win_image_path = None
        
    if win_image_path is None:
        print(f"Warning: No valid image found for uid {uid}")
        continue
    
    for ext in ext_list:
        lose_image_path = os.path.join(fake_image_dir, f"{uid}{ext}")
        if os.path.exists(lose_image_path):
            break
        lose_image_path = None
        
    if lose_image_path is None:
        print(f"Warning: No valid image found for uid {uid}")
        continue
    
    
    prompt = all_information_df.loc[all_information_df['uid'] == uid, 'prompt'].values[0]
    final_information_list.append({
        'uid': uid,
        'prompt': prompt,
        'win_image_path': win_image_path,
        'lose_image_path': lose_image_path,
        # 'mask_image_path': mask_image_path
    })

print(f"\nFinal valid samples: {len(final_information_list)}")
final_output_path = f"/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/random_{TOP_N}_images_no_anime_colorfulness-hpdv3_all-uids.csv"
pd.DataFrame(final_information_list).to_csv(final_output_path, index=False)
print(f"Saved to: {final_output_path}")

# %%
#### Get random real image and above-average colorfulness and pickscore (gap > 0.02) ####
import os
import pandas as pd
import matplotlib.pyplot as plt

all_information_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/HPDv3/real_images_uid_prompt.csv"
pickscore_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/pickscore/pickscore_score.csv"
anime_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/qwen3_anime/qwen3_anime.csv"
colorfulness_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/colorfulness/colorfulness_score.csv"

all_information_df = pd.read_csv(all_information_csv_file_path, dtype={"uid": str})
pickscore_df = pd.read_csv(pickscore_csv_file_path, dtype={"uid": str})
anime_df = pd.read_csv(anime_csv_file_path, dtype={"uid": str})
colorfulness_df = pd.read_csv(colorfulness_csv_file_path, dtype={"uid": str})

valid_real_image_uids = anime_df[anime_df['anime'] == 'no']['uid'].tolist()
valid_pickscore_uids = pickscore_df[pickscore_df['real_image_score'] - pickscore_df['fake_image_score'] > 0.02]['uid'].tolist()
colorfulness_df = colorfulness_df[colorfulness_df['uid'].isin(valid_real_image_uids)]
avg_colorfulness = colorfulness_df['real_image_score'].mean()
valid_colorfulness_uids = colorfulness_df[colorfulness_df['real_image_score'] > avg_colorfulness]['uid'].tolist()

valid_uids = list(set(valid_real_image_uids) & set(valid_colorfulness_uids) & set(valid_pickscore_uids))
print(f"valid_uids: {len(valid_uids)}")

# 从 valid_uids 中随机采样 N 张图片
# 可配置参数：选择前 N 个样本
TOP_N = 512

# 设置随机种子
random.seed(42)

# Step 1: 直接从 valid_uids 中随机选择 TOP_N 个 uid
top_N_uids = random.sample(valid_uids, min(TOP_N, len(valid_uids)))
print(f"\nStep 1: Randomly selected {len(top_N_uids)} UIDs from {len(valid_uids)} valid_uids")
print(f"Top {TOP_N} UIDs selected: {len(top_N_uids)}")

# Step 4: Generate CSV file with image paths
ext_list = [".png", ".PNG", ".jpg", ".jpeg", ".JPG", ".JPEG"]
# real_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/real"
# fake_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/fake"
real_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/real"
fake_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/fake"
# mask_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/mask"
final_information_list = []
for uid in top_N_uids:
    win_image_path, lose_image_path, mask_image_path = None, None, None
    
    for ext in ext_list:
        win_image_path = os.path.join(real_image_dir, f"{uid}{ext}")
        if os.path.exists(win_image_path):
            break
        win_image_path = None
        
    if win_image_path is None:
        print(f"Warning: No valid image found for uid {uid}")
        continue
    
    for ext in ext_list:
        lose_image_path = os.path.join(fake_image_dir, f"{uid}{ext}")
        if os.path.exists(lose_image_path):
            break
        lose_image_path = None
        
    if lose_image_path is None:
        print(f"Warning: No valid image found for uid {uid}")
        continue
    
    
    prompt = all_information_df.loc[all_information_df['uid'] == uid, 'prompt'].values[0]
    final_information_list.append({
        'uid': uid,
        'prompt': prompt,
        'win_image_path': win_image_path,
        'lose_image_path': lose_image_path,
        # 'mask_image_path': mask_image_path
    })

print(f"\nFinal valid samples: {len(final_information_list)}")
final_output_path = f"/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/random_{TOP_N}_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv"
pd.DataFrame(final_information_list).to_csv(final_output_path, index=False)
print(f"Saved to: {final_output_path}")

# %%
#### Link win image and lose image ####
import os
import pandas as pd

csv_file_name = "top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids"
base_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3"
base_target_image_dir = os.path.join(base_dir, "visualization")
os.makedirs(base_target_image_dir, exist_ok=True)

ext_list = [".png", ".PNG", ".jpg", ".jpeg", ".JPG", ".JPEG"]
df = pd.read_csv(os.path.join(base_dir, f"{csv_file_name}.csv"))
target_image_dir = os.path.join(base_target_image_dir, csv_file_name)
os.makedirs(os.path.join(target_image_dir, "real"), exist_ok=True)
os.makedirs(os.path.join(target_image_dir, "fake"), exist_ok=True)

for index, row in df.iterrows():
    uid = row['uid']
    source_win_image_path = row['win_image_path']
    source_lose_image_path = row['lose_image_path']

    win_image_name = os.path.basename(source_win_image_path)
    lose_image_name = os.path.basename(source_lose_image_path)

    target_win_image_path = os.path.join(target_image_dir, "real", win_image_name)
    target_lose_image_path = os.path.join(target_image_dir, "fake", lose_image_name)

    os.symlink(source_win_image_path, target_win_image_path)
    os.symlink(source_lose_image_path, target_lose_image_path)
    
    mask_path = os.path.join(base_dir, "mask", f"{uid}.png")
    if os.path.exists(mask_path):
        target_mask_path = os.path.join(target_image_dir, "mask", os.path.basename(mask_path))
        os.makedirs(os.path.dirname(target_mask_path), exist_ok=True)
        os.symlink(mask_path, target_mask_path)

# %%
#### Combine saliency-mask (SD-1.5) + (SD-3.5-M) ####
import os
import pandas as pd

### saliency-mask ###
all_information_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/HPDv3/real_images_uid_prompt.csv"
all_information_df = pd.read_csv(all_information_csv_file_path, dtype={"uid": str})
pickscore_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/pickscore/pickscore_score.csv"
anime_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/qwen3_anime/qwen3_anime.csv"
colorfulness_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3/colorfulness/colorfulness_score.csv"
pickscore_df = pd.read_csv(pickscore_csv_file_path, dtype={"uid": str})
anime_df = pd.read_csv(anime_csv_file_path, dtype={"uid": str})
colorfulness_df = pd.read_csv(colorfulness_csv_file_path, dtype={"uid": str})

valid_real_image_uids = anime_df[anime_df['anime'] == 'no']['uid'].tolist()
colorfulness_df = colorfulness_df[colorfulness_df['uid'].isin(valid_real_image_uids)]
avg_colorfulness = colorfulness_df['real_image_score'].mean()
valid_colorfulness_uids = colorfulness_df[colorfulness_df['real_image_score'] > avg_colorfulness]['uid'].tolist()
valid_pickscore_uids = pickscore_df[pickscore_df['real_image_score'] - pickscore_df['fake_image_score'] > 0.02]['uid'].tolist()
valid_saliency_uids = list(set(valid_real_image_uids) & set(valid_colorfulness_uids) & set(valid_pickscore_uids))
### saliency-mask ###

### full_inpainting-mask ###
full_inpainting_pickscore_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3/pickscore/pickscore_score.csv"
full_inpainting_pickscore_df = pd.read_csv(full_inpainting_pickscore_csv_file_path, dtype={"uid": str})
valid_full_inpainting_pickscore_uids = full_inpainting_pickscore_df[full_inpainting_pickscore_df['real_image_score'] - full_inpainting_pickscore_df['fake_image_score'] > 0.02]['uid'].tolist()
valid_full_inpainting_uids = list(set(valid_real_image_uids) & set(valid_full_inpainting_pickscore_uids) & set(valid_colorfulness_uids))
### full_inpainting-mask ###

# ### text-to-image ###
# text_to_image_pickscore_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/text-to-image/HPDv3/no_anime-hpdv3_all/pickscore/pickscore_score.csv"
# text_to_image_pickscore_df = pd.read_csv(text_to_image_pickscore_csv_file_path, dtype={"uid": str})
# valid_text_to_image_pickscore_uids = text_to_image_pickscore_df[text_to_image_pickscore_df['real_image_score'] - text_to_image_pickscore_df['fake_image_score'] > 0.02]['uid'].tolist()
# valid_text_to_image_uids = list(set(valid_real_image_uids) & set(valid_text_to_image_pickscore_uids) & set(valid_colorfulness_uids))
# ### text-to-image ###

# ### SD-3.5-M ###
# sd_3_5_m_csv_file_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net-next-sd3.5m-inpainting/HPDv3/pickscore/pickscore_score.csv"
# sd_3_5_m_pickscore_df = pd.read_csv(sd_3_5_m_csv_file_path, dtype={"uid": str})
# valid_sd_3_5_m_pickscore_uids = sd_3_5_m_pickscore_df[sd_3_5_m_pickscore_df['real_image_score'] - sd_3_5_m_pickscore_df['fake_image_score'] > 0.02]['uid'].tolist()
# valid_sd_3_5_m_uids = list(set(valid_real_image_uids) & set(valid_sd_3_5_m_pickscore_uids) & set(valid_colorfulness_uids))
# ### SD-3.5-M ###



valid_uids = list(set(valid_saliency_uids) & set(valid_full_inpainting_uids))

# 按 real_image_score 降序排序，取 top 512 uids（使用 saliency pickscore）
TOP_N = 512
saliency_inpainting_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/HPDv3"
full_inpainting_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/full_inpainting-strength_0.8-guidance_scale_3.0/HPDv3"

pickscore_valid_df = pickscore_df[pickscore_df['uid'].isin(valid_uids)].copy()
pickscore_valid_df = pickscore_valid_df.sort_values('real_image_score', ascending=False)
# 只保留「saliency 与 sd3.5m 的 real/fake 文件均存在」的 uid，保证两个 CSV 样本一致
candidate_uids = []
for uid in pickscore_valid_df['uid'].tolist():
    saliency_ok = os.path.exists(os.path.join(saliency_inpainting_dir, "real", f"{uid}.png")) and os.path.exists(os.path.join(saliency_inpainting_dir, "fake", f"{uid}.png"))
    full_inpainting_ok = os.path.exists(os.path.join(full_inpainting_dir, "real", f"{uid}.png")) and os.path.exists(os.path.join(full_inpainting_dir, "fake", f"{uid}.png"))
    if saliency_ok and full_inpainting_ok:
        candidate_uids.append(uid)
        if len(candidate_uids) >= TOP_N:
            break
    else:
        print(f"Warning: No valid image found for uid {uid}")
        continue
valid_uids = candidate_uids
print(f"Top {TOP_N} uids by real_image_score (both saliency & full-inpainting files exist); actual count: {len(valid_uids)}")

base_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/saliency_inpainting-full_inpainting-strength_0.8-guidance_scale_3.0"
os.makedirs(base_dir, exist_ok=True)

saliency_inpainting_information_list = []
full_inpainting_information_list = []
for uid in valid_uids:
    ### append saliency-mask ###
    win_image_path = os.path.join(saliency_inpainting_dir, "real", f"{uid}.png")
    lose_image_path = os.path.join(saliency_inpainting_dir, "fake", f"{uid}.png")
    prompt = all_information_df.loc[all_information_df['uid'] == uid, 'prompt'].values[0]
    saliency_inpainting_information_list.append({
        'uid': uid,
        'prompt': prompt,
        'win_image_path': win_image_path,
        'lose_image_path': lose_image_path,
    })
    ### append saliency-mask ###
    
    ### append SD-3.5-M ###
    win_image_path = os.path.join(full_inpainting_dir, "real", f"{uid}.png")
    lose_image_path = os.path.join(full_inpainting_dir, "fake", f"{uid}.png")
    full_inpainting_information_list.append({
        'uid': uid,
        'prompt': prompt,
        'win_image_path': win_image_path,
        'lose_image_path': lose_image_path,
    })
    ### append SD-3.5-M ###

# combined_information_list = saliency_inpainting_information_list + text_to_image_information_list
# finla_output_path = f"/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/saliency_inpainting-text_to_image/top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv"
# pd.DataFrame(combined_information_list).to_csv(finla_output_path, index=False)
# print(f"Saved to: {finla_output_path}")

# final_output_path = f"/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/saliency_inpainting-full_inpainting-strength_0.8-guidance_scale_3.0/saliency_inpainting-strength_0.8-guidance_scale_3.0-top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv"
# pd.DataFrame(saliency_inpainting_information_list).to_csv(final_output_path, index=False)
# print(f"Saved to: {final_output_path}")

# final_output_path = f"/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/saliency_inpainting-full_inpainting-strength_0.8-guidance_scale_3.0/full_inpainting-strength_0.8-guidance_scale_3.0-top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv"
# pd.DataFrame(full_inpainting_information_list).to_csv(final_output_path, index=False)
# print(f"Saved to: {final_output_path}")

total_information_list = saliency_inpainting_information_list + full_inpainting_information_list
final_output_path = f"/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/saliency_inpainting-full_inpainting-strength_0.8-guidance_scale_3.0/top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv"
pd.DataFrame(total_information_list).to_csv(final_output_path, index=False)
print(f"Saved to: {final_output_path}")
# Out:
# Top 512 uids by real_image_score (both saliency & full-inpainting files exist); actual count: 512
# Saved to: /data_center/data2/dataset/chenwy/21164-data/dpo_dataset/saliency_inpainting-full_inpainting-strength_0.8-guidance_scale_3.0/top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all-uids.csv
