# %%
#### Get csv file from image directory ####
import os
import pandas as pd

base_image_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/pick-a-pic-v2/DiffusionDRO-pick-a-pic-v2-top_4096"
target_csv_path = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/top_4096_images.csv"

data = []
for folder_name in sorted(os.listdir(base_image_dir)):
    folder_path = os.path.join(base_image_dir, folder_name)
    
    if not os.path.isdir(folder_path):
        continue
    
    caption_path = os.path.join(folder_path, "caption.txt")
    if os.path.exists(caption_path):
        with open(caption_path, 'r', encoding='utf-8') as f:
            prompt = f.read().strip()
        
        # 使用文件夹名作为 uid
        uid = folder_name
        
        data.append({
            'uid': uid,
            'prompt': prompt
        })


os.makedirs(os.path.dirname(target_csv_path), exist_ok=True)
df = pd.DataFrame(data)
df.to_csv(target_csv_path, index=False, encoding='utf-8')

print(f"成功处理 {len(df)} 条数据")
print(f"CSV 文件已保存至: {target_csv_path}")
print(f"\n前5条数据预览:")
print(df.head())
# Out:
# 成功处理 4096 条数据
# CSV 文件已保存至: /data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/top_4096_images.csv
#
# 前5条数据预览:
#     uid                                             prompt
# 0  0000             anime girl eating pizza, hd, 4k, anime
# 1  0001                                Whorish Asian Woman
# 2  0002  A robot holding a sign that says "Gen-2", vect...
# 3  0003                                  Whorish Orc Woman
# 4  0004   A steampunk octopus playing the drums on a beach

# %%
#### copy the images to the target directory ####
import shutil
import glob

source_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/pick-a-pic-v2/DiffusionDRO-pick-a-pic-v2-top_4096"
target_dir = "/data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/top_4096"

os.makedirs(target_dir, exist_ok=True)

copied_count = 0
for folder_name in sorted(os.listdir(source_dir)):
    folder_path = os.path.join(source_dir, folder_name)
    
    if not os.path.isdir(folder_path):
        continue
    
    png_files = glob.glob(os.path.join(folder_path, "*.png"))
    
    for png_file in png_files:
        filename = os.path.basename(png_file)
        target_path = os.path.join(target_dir, filename)
        
        shutil.copy2(png_file, target_path)
        copied_count += 1

print(f"成功复制 {copied_count} 张图片到: {target_dir}")
# Out:
# 成功复制 4096 张图片到: /data_center/data2/dataset/chenwy/21164-data/dpo_dataset/u2net_next_inpainting/pick-a-pic-v2-top_4096/top_4096
