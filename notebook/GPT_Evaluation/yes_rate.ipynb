# %%
#### Is the image in a realistic style? ####
import os
import pandas as pd
# gpt_name = "gpt-5.1-chat-latest"
# gpt_name = "gemini-3-pro-preview"
gpt_name = "claude-sonnet-4-5-20250929"
method = "sd-3-5-medium"
method = "FlowGRPO-PickScore"
# method = "irl_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all_lr_0.0002_ckpt_3200-dpo_top_512_images_no_anime_colorfulness_pickscore_0.02-hpdv3_all"

csv_file_path = f"/data_center/data2/dataset/chenwy/21164-data/diffusion-dpo/sd-3-5-medium/GPT_Evaluation/OneIG-Bench-Portrait-style_evaluation/{method}/{gpt_name}_style_classification.csv"
df = pd.read_csv(csv_file_path)
# 统计 is_realistic 列中 "Yes" 的数量（不区分大小写，去除空格）
yes_count = (df['is_realistic'].str.strip().str.lower() == 'yes').sum()
total_count = len(df)
yes_rate = yes_count / total_count * 100 if total_count > 0 else 0

print(f"总样本数: {total_count}")
print(f"'Yes' 的数量: {yes_count}")
print(f"'Yes' 的比例: {yes_rate:.2f}%")
# Out:
# 总样本数: 120
# 'Yes' 的数量: 9
# 'Yes' 的比例: 7.50%
